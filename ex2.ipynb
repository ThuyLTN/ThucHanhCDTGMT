# %% [markdown]
# <a href="https://colab.research.google.com/github/ThuyLTN/ThucHanhCDTGMT/blob/master/ex2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python --version
# Out:
# Python 3.6.7

# %%
# !wget https://upload.wikimedia.org/wikipedia/commons/9/98/Tom_Hanks_face.jpg
# !mv Tom_Hanks_face.jpg ivan.jpg
# Out:
# --2019-01-23 11:20:55--  https://upload.wikimedia.org/wikipedia/commons/9/98/Tom_Hanks_face.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 208.80.154.240, 2620:0:861:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|208.80.154.240|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 124494 (122K) [image/jpeg]
# Saving to: ‘Tom_Hanks_face.jpg’
#
# Tom_Hanks_face.jpg  100%[===================>] 121.58K  --.-KB/s    in 0.05s
#
# 2019-01-23 11:20:55 (2.51 MB/s) - ‘Tom_Hanks_face.jpg’ saved [124494/124494]

# %%
# !pip install mtcnn
# Out:
# Collecting mtcnn
#   Downloading https://files.pythonhosted.org/packages/0b/f5/d62ac2bdf1c683b7650268305db3126323a7b6a2f6390273038285fa9e3f/mtcnn-0.0.8.tar.gz (2.3MB)
#     100% |████████████████████████████████| 2.3MB 6.1MB/s
# Building wheels for collected packages: mtcnn
# done
#   Stored in directory: /root/.cache/pip/wheels/be/dd/12/bccde6b95f576af24256f6f1a2e4087eb8488405a6c107e13c
# Successfully built mtcnn
# Installing collected packages: mtcnn
# Successfully installed mtcnn-0.0.8

# %%
from mtcnn.mtcnn import MTCNN
import cv2

img = cv2.imread("ivan.jpg")
detector = MTCNN()
print(detector.detect_faces(img))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/mtcnn/layer_factory.py:211: calling reduce_max (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/mtcnn/layer_factory.py:213: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# [{'box': [83, 93, 169, 216], 'confidence': 0.9997074007987976, 'keypoints': {'left_eye': (127, 170), 'right_eye': (201, 179), 'nose': (153, 225), 'mouth_left': (120, 250), 'mouth_right': (191, 260)}}]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.imshow(img)

# %%
[{'box': [277, 90, 48, 63], 'keypoints': {'nose': (303, 131), 'mouth_right': (313, 141), 'right_eye': (314, 114), 'left_eye': (291, 117), 'mouth_left': (296, 143)}, 'confidence': 0.99851983785629272}]
